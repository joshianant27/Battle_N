# %% [markdown]
# # Battle of Neighborhoods (week 1)

# %% [markdown]
# ## The Background Discussion
#
# There are lot of international people who come to the United States of America some come come to find jobs, some to study, some to travel. Therefore, this project aims to aid those people who are new to the land and wishes to explore the neighborhoods around them. In this project I have used the data of New York City in json format and the foursquare api to retrieve information regarding the venues.

# %% [markdown]
# ## The Problem Statement
#
# Mr. A has recently shifted to <font color=red>**NEW YORK CITY**</font>. Since he is new to the town he has no idea about the city. He have no knowledge about the cuisine, entertainment or neighborhoods. Therefore he requires a program where he enter the name of the neighborhood he wants to know about. How many hospitals,restaurants or movie theatres are there in that particular neighbourhood.

# %% [markdown]
# ## The Solution
# We will create a menu of <font color=green>Top Ten</font> most important requirements of Mr.A for example hospitals,hotels,casinos, zoo etc. Thereafter Mr.A will be required to enter a number from 1-10 and the name of the neighborhood he wants to know about. Since we will use only New York City data the neighborhoods name must belong to New York. After that we will use foursquare api to generate data for the request and display it on the map using foilum library.

# %% [markdown]
# # DATA

# %% [markdown]
# We will be using <font color='red'> New York City</font> data, available to us in json format.
# (Since, I have already downloaded the data I will be using it from my local hard drive.)

# %% [markdown]
# ### Let us import some important libraries.

# %%
import numpy as np
import pandas as pd
import requests
import folium
from geopy.geocoders import Nominatim
import json
from pandas.io.json import json_normalize

# %% [markdown]
# ### Let us get the data.

# %%
with open('C:/Users/Asus/Downloads/newyork_data.json') as json_data:
    newyork_data=json.load(json_data)

# %%
newyork_data
df1=newyork_data['features']
df1[0]
# Out:
# {'type': 'Feature',
#  'id': 'nyu_2451_34572.1',
#  'geometry': {'type': 'Point',
#   'coordinates': [-73.84720052054902, 40.89470517661]},
#  'geometry_name': 'geom',
#  'properties': {'name': 'Wakefield',
#   'stacked': 1,
#   'annoline1': 'Wakefield',
#   'annoline2': None,
#   'annoline3': None,
#   'annoangle': 0.0,
#   'borough': 'Bronx',
#   'bbox': [-73.84720052054902,
#    40.89470517661,
#    -73.84720052054902,
#    40.89470517661]}}

# %%
columns_name=['Borough','Neighborhoods','Latitude','Longitude']

newyork_df=pd.DataFrame(columns=columns_name)
newyork_df
# Out:
# Empty DataFrame
# Columns: [Borough, Neighborhoods, Latitude, Longitude]
# Index: []

# %%
for i in df1:
    borough=name=i['properties']['borough']
    name=i['properties']['name']
    coordinates=i['geometry']['coordinates']
    latitude=coordinates[1]
    longitude=coordinates[0]
    newyork_df=newyork_df.append({'Borough':borough,
                 'Neighborhoods':name,
                 'Latitude':latitude,
                 'Longitude':longitude},ignore_index=True)

# %%
newyork_df.head()
# Out:
#   Borough Neighborhoods   Latitude  Longitude
# 0   Bronx     Wakefield  40.894705 -73.847201
# 1   Bronx    Co-op City  40.874294 -73.829939
# 2   Bronx   Eastchester  40.887556 -73.827806
# 3   Bronx     Fieldston  40.895437 -73.905643
# 4   Bronx     Riverdale  40.890834 -73.912585

# %%
print('The dataframe has {} Boroughs and {} Neighborhoods'.format(len(newyork_df['Borough'].unique()),newyork_df['Neighborhoods'].shape[0]))
# Out:
# The dataframe has 5 Boroughs and 306 Neighborhoods

# %% [markdown]
# ### The above newyork_df DataFrame will be used to plot points on the map and then take the inputs from the user and then plot required details on the map.

# %% [markdown]
# ## Plot all the neighborhoods on the New York map (Week 2).

# %%
address='New York City,NY'
geolocator=Nominatim(user_agent="ny_explorer")
location=geolocator.geocode(address) #retrieve co-ordinates of the New York city
latitude=location.latitude
longitude=location.longitude
print('The geograpical coordinate of New York City are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of New York City are 40.7127281, -74.0060152.

# %%
map_newyork=folium.Map(location=[latitude,longitude],zoom_start=11)
for lat,lon,borough,neighborhood in zip(newyork_df['Latitude'],newyork_df['Longitude'],newyork_df['Borough'],newyork_df['Neighborhoods']):
    label='{},{}'.format(neighborhood,borough)
    label=folium.Popup(label,parse_html=True)
    folium.CircleMarker(
    [lat,lon],
    radius=5,
    popup=label,
    color='blue',
    fill=True,
    fill_color='#3186cc',
    fill_opacity=0.7,
    parse_html=False).add_to(map_newyork)

map_newyork
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# ### Define the Foursquare Api Client-ID and Client-Secret

# %%
CLIENT_ID='WY04EP2PLIS1BOQISJXQLPVHLET2COE2SWVZ05N4WMNJDQIU'
CLIENT_SECRET='DSS32L3SW0ELM4USMWDOFUTJTOWRTZTNXUORVAIKXLNDDTHW'
LIMIT=100

# %% [markdown]
# ### Define the Category-ID for the 10 most important types of venues according to Mr.A

# %%
Hospital_ID='4bf58dd8d48988d196941735'
Restaurant_ID='4d4b7105d754a06374d81259'
cafe_ID='4bf58dd8d48988d16d941735'
DesertShop_ID='4bf58dd8d48988d1d0941735'
Bar_ID='4bf58dd8d48988d116941735'
Theatre_ID='4bf58dd8d48988d17f941735'
Gym_ID='4bf58dd8d48988d176941735'
Water_ID='4bf58dd8d48988d193941735'
Park_ID='4bf58dd8d48988d163941735'
Zoo_ID='4bf58dd8d48988d17b941735'

category_ID=[Hospital_ID,Restaurant_ID,cafe_ID,DesertShop_ID,Bar_ID,Theatre_ID,Gym_ID,Water_ID,Park_ID,Zoo_ID]

# %% [markdown]
# ### Print the menu

# %%
print("          INFORMATION MENU           ")
print("""
1. Enter 1 for Hospitals
2. Enter 2 for Restaurants
3. Enter 3 for Cafes
4. Enter 4 for Deasert Shops
5. Enter 5 for Bars
6. Enter 6 for Theatres
7. Enter 7 for Gym
8. Enter 8 for Water Parks
9. Enter 9 for Parks
10.Enter 10 for Zoo""")

num=int(input()) # I will enter 2 (for example)
# Out:
#           INFORMATION MENU
#
# 1. Enter 1 for Hospitals
# 2. Enter 2 for Restaurants
# 3. Enter 3 for Cafes
# 4. Enter 4 for Deasert Shops
# 5. Enter 5 for Bars
# 6. Enter 6 for Theatres
# 7. Enter 7 for Gym
# 8. Enter 8 for Water Parks
# 9. Enter 9 for Parks
# 10.Enter 10 for Zoo
# 2

# %%
print(" Enter the name of the Neighborhood ")
neigh=input() # I will enter Riverdale for example
# Out:
#  Enter the name of the Neighborhood
# Riverdale

# %% [markdown]
# ## Retrieve the co-ordinates of the neighborhood (Riverdale)

# %%
index=newyork_df[newyork_df['Neighborhoods']==neigh].index.values
for i in newyork_df['Neighborhoods']:
    if neigh==i:
        neigh_lat=newyork_df.loc[index[0],'Latitude']
        neigh_lon=newyork_df.loc[index[0],'Longitude']

print("The latitudes and longitudes for the neighbourhood {} are {},{} ".format(neigh,neigh_lat,neigh_lon))
# Out:
# The latitudes and longitudes for the neighbourhood Riverdale are 40.890834493891305,-73.9125854610857

# %% [markdown]
# ## Define the URL for the get request of Foursquare API

# %%
radius=1000
url='https://api.foursquare.com/v2/venues/search?ll={},{}&categoryId={}&client_id={}&client_secret={}&radius={}&limit={}&v=20180628'.format(
neigh_lat,
neigh_lon,
category_ID[(num-1)], #(num-1) because list range is [0-9]
CLIENT_ID,
CLIENT_SECRET,
radius,
LIMIT)

url
# Out:
# 'https://api.foursquare.com/v2/venues/search?ll=40.890834493891305,-73.9125854610857&categoryId=4d4b7105d754a06374d81259&client_id=WY04EP2PLIS1BOQISJXQLPVHLET2COE2SWVZ05N4WMNJDQIU&client_secret=DSS32L3SW0ELM4USMWDOFUTJTOWRTZTNXUORVAIKXLNDDTHW&radius=1000&limit=100&v=20180628'

# %% [markdown]
# ## Retrieve the data regarding the venue

# %%
result=requests.get(url).json()
result
# Out:
# {'meta': {'code': 200, 'requestId': '6091ba481a767d4f3ddac8d1'},
#  'response': {'venues': [{'id': '5bb5167a46e1b6002c3e1776',
#     'name': "Menchie's",
#     'location': {'address': '3555 Johnson Ave',
#      'crossStreet': 'at W 236th St',
#      'lat': 40.886388000000004,
#      'lng': -73.910025,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.886388000000004,
#        'lng': -73.910025},
#       {'label': 'entrance', 'lat': 40.88655, 'lng': -73.909847}],
#      'distance': 539,
#      'postalCode': '10463',
#      'cc': 'US',
#      'city': 'Bronx',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['3555 Johnson Ave (at W 236th St)',
#       'Bronx, NY 10463',
#       'United States']},
#     'categories': [{'id': '512e7cae91d4cbb4e5efe0af',
#       'name': 'Frozen Yogurt Shop',
#       'pluralName': 'Frozen Yogurt Shops',
#       'shortName': 'Yogurt',
# ...

# %% [markdown]
# ## Now we will clean the data and covert it into a DataFrame

# %%
output=result['response']
output['venues'][0]
# Out:
# {'id': '5bb5167a46e1b6002c3e1776',
#  'name': "Menchie's",
#  'location': {'address': '3555 Johnson Ave',
#   'crossStreet': 'at W 236th St',
#   'lat': 40.886388000000004,
#   'lng': -73.910025,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 40.886388000000004,
#     'lng': -73.910025},
#    {'label': 'entrance', 'lat': 40.88655, 'lng': -73.909847}],
#   'distance': 539,
#   'postalCode': '10463',
#   'cc': 'US',
#   'city': 'Bronx',
#   'state': 'NY',
#   'country': 'United States',
#   'formattedAddress': ['3555 Johnson Ave (at W 236th St)',
#    'Bronx, NY 10463',
#    'United States']},
#  'categories': [{'id': '512e7cae91d4cbb4e5efe0af',
#    'name': 'Frozen Yogurt Shop',
#    'pluralName': 'Frozen Yogurt Shops',
#    'shortName': 'Yogurt',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/frozenyogurt_',
#     'suffix': '.png'},
#    'primary': True}],
#  'delivery': {'id': '1709979',
# ...

# %%
venue=pd.DataFrame(columns=['Name','Latitude','Longitude'])
venue
# Out:
# Empty DataFrame
# Columns: [Name, Latitude, Longitude]
# Index: []

# %%
for row in output['venues']:
    venue=venue.append({'Name':row['name'],
                       'Latitude':row['location']['lat'],
                       'Longitude':row['location']['lng']},ignore_index=True)

# %%
venue.head()
# Out:
#                   Name   Latitude  Longitude
# 0            Menchie's  40.886388 -73.910025
# 1               Metate  40.886061 -73.910030
# 2  Blue Bay Restaurant  40.886358 -73.909896
# 3              Wendy's  40.884697 -73.901217
# 4                 Neem  40.886483 -73.909830

# %% [markdown]
# ## Plot the points of each venue on the map of the neighbourhood

# %%
map_neighborhood=folium.Map(location=[neigh_lat,neigh_lon],zoom_start=14)
for i in range(0,len(venue)):
        folium.Marker(
        location=[venue.iloc[i]['Latitude'],venue.iloc[i]['Longitude']],
        popup=venue.iloc[i]['Name']
        ).add_to(map_neighborhood)
map_neighborhood
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# ## If we click on any of the popups displayed above we will get the name of the venue.

# %% [markdown]
# # The above process can be repeated n number of times for all the neighborhoods in New York.
# ## This project will be mainly helpful for the people who are new in neighborhood and also it will aid to someone who is lost and needs immediate help.

# %% [markdown]
# # Thank You
